# %%
import numpy as np
import random
from PIL import Image
import matplotlib.pyplot as plt
import time

class DitheringMaker:
    '''
    Performs dithering on an image using the classical Floyd-Steinberg dithering algorithm. The
    dithering isn't applied to the last row or the edge columns. Instead the last row and edge
    columns are made all white as this will later not add any vertices when we extract vertices
    from the dithering.

    Members
    -------
    dithering : Numpy array of Int of Shape(n_rows, nCol)
        The array holding the dithering of the image. Note that the last row and edge columns will
        always be converted to white (i.e. 255).

    row_disp : Numpy array of Int of shape (2, 3)
        The row offsets to apply the diffusions to.

    col_disp : Numpy array of Int of shape (2, 3)
        The column offsets to apply the diffusions to.

    diffusion_prop : Numpy array of Float of shape (2, 3)
        The Floyd-Steinberg coefficients for diffusing the error in the
        dithering.
    '''

    def __init__(self):
        '''
        Initialize the dithering to None as we haven't performed any yet.

        The displacement of indices and the diffusion coefficients are for the classic
        Floyd-Steinberg dithering algorithm.
        '''

        self.dithering = None

        self.row_disp = np.full((2, 3), np.arange(0, 2)[:, np.newaxis], dtype = 'int')
        self.col_disp = np.full((2, 3), np.arange(-1, 2), dtype = 'int')
        self.diffusion_prop = np.array([[0, 0, 7],
                                        [3, 5, 1]]) / 16

    def make_dithering(self, pixels, cutoff = 255 / 2):
        '''
        Apply the classic Floyd-Steinberg dithering algorithm, but for simplicity
        we just make the edge columns and the last row all white (which will give
        us no vertices when we later extract vertices).

        Parameters
        ----------
        pixels : Numpy array of Int of shape (n_rows, n_cols)
            The gray scale pixels to apply the dithering to.

        cutoff : Float
            The cut off for making a dithering pixel either 0 or 255.

        Returns
        -------
        Numpy array of Int of Shape (n_rows, n_cols)
            The final dithering; each pixel is either 0 or 255 (black or white).
        '''

        # We use Floyd-Steinberg dithering. Error diffusion is
        # _     x     7/16
        # 3/16  5/16  1/16

        self.dithering = pixels.copy().astype('float')

        n_rows, n_cols = pixels.shape

        # Initialize the first column to be white.

        self.dithering[:][0] = 255

        # Iterate over each row, applying the dithering and diffusing the error.

        for row in range(n_rows - 1):
            for col in range(1, n_cols - 1):

                dither, error = self.get_dither(row, col, cutoff)
                self.dithering[row, col] = dither
                self.diffuse_error(error, row, col)

        # Make the last column and the last row all white.

        self.dithering[:, -1] = 255
        self.dithering[-1, :] = 255


        # Convert dithering to Numpy array of Int.

        self.dithering = self.dithering.astype('int')

        return self.dithering

    def get_dither(self, row, col, cutoff):
        '''
        Turn (dithered) pixel into either 0 or 255 using cutoff.

        Parameters
        ----------
        row : Int
            Index of pixel row.

        col : Int
            Index of pixel column.

        cutoff : Float
            The cutoff value to use for converting dithering value to either 0 or 255
            (black or white).

        Returns
        -------
        dither : Float
            Floating point value that is either 0.0 or 255.0 (black or white).

        error : Float
            The error in applying the conversion, this needs to be diffused to other pixels
            according to the dithering algorithm.
        '''

        pixel = self.dithering[row][col]

        if pixel < cutoff:
            dither = 0.0
        else:
            dither = 255.0

        error = pixel - dither

        return dither, error

    def diffuse_error(self, error, row, col):
        '''
        Diffuse the error from a (dithered) pixel conversion to black or white. The diffusion
        is applied to the neighbors of the pixel at position [row, col] according to the
        Floyd-Steinberg algorithm.

        Parameters
        ----------
        error : Float
            The size of error to diffuse to other pixels.

        row : Int
            The row index of where the conversion took place.

        col : Int
            The column index of where the conversion took place.
        '''

        self.dithering[row + self.row_disp, col + self.col_disp] += error * self.diffusion_prop

def get_vertices(dithering):
    '''
    Get the vertices from a black and white image, not grayscale (in particular a dithered image).
    Every black pixel (value 0.0) gives a vertex.

    Parameters
    ----------
    dithering : Numpy array of shape (n_rows, n_cols)
        The array of pixels for the dithered image.

    Returns
    -------
    Numpy array of shape (nVertices, 2)
        The xy-coordinates of the vertices.
    '''

    n_rows, n_cols = dithering.shape

    # Each black pixel gives a vertex.
    keep_pixel_mask = (dithering == 0)

    # Get the row and column indices of the vertices.

    rows = np.full(dithering.shape, np.arange(n_rows)[:, np.newaxis]).reshape(-1)
    cols = np.full(dithering.shape, np.arange(n_cols)).reshape(-1)

    rows = rows[keep_pixel_mask.reshape(-1)]
    cols = cols[keep_pixel_mask.reshape(-1)]

    # Get the xy-coordinate of the vertices. Make sure to transform row index so
    # that the last row has y value 0.

    vertices = np.stack([cols, n_rows - rows], axis = -1)

    return vertices


def getPixels(image, ds=1):
    '''
    Get the pixels as a numpy array from a PIL image.
    We can take the mean of each ds x ds subsquare as an array element inorder to down-size
    the size of the image if we want to.

    Parameters
    ----------
    image : PIL Image
        The PIL image to convert.

    ds : Int
        We take the mean of each ds x ds sub-square for a single element of our array.

    Returns
    -------
    2d Numpy array of floats
        The converted values of the pixels in the image. We use mean because we
        possibly took a mean over sub-squares.
    '''
    imwidth, imheight = image.size
    pixels = list(image.getdata())
    pixels = np.array(pixels).reshape((imheight, imwidth))
    pixels = [[pixels[i:i + ds, j:j + ds].mean() for j in np.arange(0, imwidth, ds)]
              for i in np.arange(0, imheight, ds)]
    return np.array(pixels)

class TSP_ABC:
    def __init__(self, image_path, num_bees=100, max_cycles=100):
        self.image_path = image_path
        self.num_bees = num_bees
        self.max_cycles = max_cycles

    def process_image(self):
        image = Image.open(self.image_path).convert('L')
        pixels = getPixels(image, ds=5)
        ditherer = DitheringMaker()
        self.dithered_image = ditherer.make_dithering(pixels)
        self.vertices = get_vertices(self.dithered_image)
        self.distance_matrix = self.calculate_distance_matrix(self.vertices)

    def calculate_distance_matrix(self, vertices):
        diff = np.expand_dims(vertices, axis=1) - np.expand_dims(vertices, axis=0)
        return np.sqrt((diff ** 2).sum(axis=2))

    def fitness(self, tour):
        return np.sum(self.distance_matrix[np.roll(tour, 1), tour])

    def initialize_population(self):
        population = []
        for _ in range(self.num_bees):
            tour = np.random.permutation(len(self.vertices))
            population.append(tour)
        return population

    def two_opt_swap(self, tour):
        i, j = sorted(random.sample(range(len(tour)), 2))
        tour[i:j+1] = tour[i:j+1][::-1]
        return tour

    def select_solution(self, current_solution, candidate_solution):
        if self.fitness(candidate_solution) < self.fitness(current_solution):
            return candidate_solution
        return current_solution

    def abc_algorithm(self):
        population = self.initialize_population()
        fitnesses = [self.fitness(ind) for ind in population]
        best_fitness = float('inf')
        best_solution = None

        non_improving_cycles = 0
        max_non_improving_cycles = 30

        for cycle in range(self.max_cycles):
            # Employed Bee Phase
            for i in range(self.num_bees):
                candidate_solution = self.two_opt_swap(population[i].copy())
                population[i] = self.select_solution(population[i], candidate_solution)
                fitnesses[i] = self.fitness(population[i])

            # Onlooker Bee Phase
            max_fitness = max(fitnesses)
            probabilities = [(max_fitness - f + 1) / sum(max_fitness - np.array(fitnesses) + 1) for f in fitnesses]
            for _ in range(self.num_bees):
                selected_index = np.random.choice(self.num_bees, p=probabilities)
                candidate_solution = self.two_opt_swap(population[selected_index].copy())
                new_solution = self.select_solution(population[selected_index], candidate_solution)
                new_fitness = self.fitness(new_solution)
                if new_fitness < fitnesses[selected_index]:
                    population[selected_index] = new_solution
                    fitnesses[selected_index] = new_fitness

            # Scout Bee Phase
            if non_improving_cycles >= max_non_improving_cycles:
                for i in range(self.num_bees // 10):
                    idx = random.randint(0, self.num_bees - 1)
                    population[idx] = np.random.permutation(len(self.vertices))
                    fitnesses[idx] = self.fitness(population[idx])
                non_improving_cycles = 0

            current_best_idx = np.argmin(fitnesses)
            if fitnesses[current_best_idx] < best_fitness:
                best_fitness = fitnesses[current_best_idx]
                best_solution = population[current_best_idx]
                non_improving_cycles = 0
            else:
                non_improving_cycles += 1

            print(f"Cycle {cycle + 1}: Best Fitness = {best_fitness}")

        return best_solution, best_fitness

    def plot_path(self, best_solution):
        '''
        Plot the best path found by the solver.
        '''
        best_path = [self.vertices[i] for i in best_solution] + [self.vertices[best_solution[0]]]
        x, y = zip(*best_path)
        plt.figure(figsize=(10, 10))
        plt.plot(x, y, '-o', markersize=3, linewidth=1)
        plt.title("Best Path")
        plt.show()

    def solve(self):
        '''
        Solver
        '''
        start_time = time.time()
        self.process_image()
        best_solution, best_fitness = self.abc_algorithm()
        end_time = time.time()
        exec_time = end_time - start_time
        print("Best solution:", best_fitness)
        self.plot_path(best_solution)
        print(f"Execution Time: {exec_time:.2f} seconds")

if __name__ == "__main__":
    solver = TSP_ABC("flower.png", num_bees=100, max_cycles=5000)
    solver.solve()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# Cycle 2: Best Fitness = 7490.607112283174
# Cycle 3: Best Fitness = 7486.842630562334
# Cycle 4: Best Fitness = 7485.156041156425
# Cycle 5: Best Fitness = 7462.440952145267
# Cycle 6: Best Fitness = 7448.8780886679215
# Cycle 7: Best Fitness = 7431.738996051663
# Cycle 8: Best Fitness = 7423.25592932245
# Cycle 9: Best Fitness = 7423.25592932245
# Cycle 10: Best Fitness = 7423.25592932245
# Cycle 11: Best Fitness = 7423.25592932245
# Cycle 12: Best Fitness = 7423.25592932245
# Cycle 13: Best Fitness = 7422.315775999856
# Cycle 14: Best Fitness = 7417.735637017277
# Cycle 15: Best Fitness = 7399.220164865745
# Cycle 16: Best Fitness = 7379.245044062713
# Cycle 17: Best Fitness = 7350.513804647473
# Cycle 18: Best Fitness = 7325.9111049485655
# Cycle 19: Best Fitness = 7306.8612293274455
# Cycle 20: Best Fitness = 7305.315849972884
# Cycle 21: Best Fitness = 7305.315849972884
# Cycle 22: Best Fitness = 7297.478958441434
# Cycle 23: Best Fitness = 7297.478958441434
# Cycle 24: Best Fitness = 7270.527679728057
# Cycle 25: Best Fitness = 7258.327328618492
# Cycle 26: Best Fitness = 7235.515607605166
# Cycle 27: Best Fitness = 7232.954221531836
# Cycle 28: Best Fitness = 7204.838643030012
# Cycle 29: Best Fitness = 7112.157115287059
# Cycle 30: Best Fitness = 7087.273062662074
# Cycle 31: Best Fitness = 7081.2855739138795
# Cycle 32: Best Fitness = 7074.312747565937
# Cycle 33: Best Fitness = 7034.8909631589195
# Cycle 34: Best Fitness = 7004.720067081107
# Cycle 35: Best Fitness = 6997.373313004617
# Cycle 36: Best Fitness = 6992.192868780753
# Cycle 37: Best Fitness = 6984.64590081151
# Cycle 38: Best Fitness = 6942.020108584675
# Cycle 39: Best Fitness = 6938.019302514057
# Cycle 40: Best Fitness = 6938.019302514057
# Cycle 41: Best Fitness = 6919.3594896882305
# Cycle 42: Best Fitness = 6919.3594896882305
# Cycle 43: Best Fitness = 6919.3594896882305
# Cycle 44: Best Fitness = 6903.670240173685
# Cycle 45: Best Fitness = 6903.670240173685
# Cycle 46: Best Fitness = 6903.670240173685
# Cycle 47: Best Fitness = 6903.670240173685
# Cycle 48: Best Fitness = 6891.660139430918
# Cycle 49: Best Fitness = 6882.523767010186
# Cycle 50: Best Fitness = 6844.113777244924
# Cycle 51: Best Fitness = 6844.113777244924
# Cycle 52: Best Fitness = 6844.113777244924
# Cycle 53: Best Fitness = 6829.89248176078
# Cycle 54: Best Fitness = 6804.974925229596
# Cycle 55: Best Fitness = 6804.057008987893
# Cycle 56: Best Fitness = 6803.132094932214
# Cycle 57: Best Fitness = 6788.920404176175
# Cycle 58: Best Fitness = 6787.112430241895
# Cycle 59: Best Fitness = 6787.112430241895
# Cycle 60: Best Fitness = 6787.112430241895
# Cycle 61: Best Fitness = 6787.112430241895
# Cycle 62: Best Fitness = 6787.112430241895
# Cycle 63: Best Fitness = 6787.112430241895
# Cycle 64: Best Fitness = 6787.112430241895
# Cycle 65: Best Fitness = 6787.112430241895
# Cycle 66: Best Fitness = 6766.545562625298
# Cycle 67: Best Fitness = 6746.157719579977
# Cycle 68: Best Fitness = 6739.538604844905
# Cycle 69: Best Fitness = 6736.999252892194
# Cycle 70: Best Fitness = 6654.547064320352
# Cycle 71: Best Fitness = 6653.281525948951
# Cycle 72: Best Fitness = 6653.281525948951
# Cycle 73: Best Fitness = 6649.385601576454
# Cycle 74: Best Fitness = 6636.393520676136
# Cycle 75: Best Fitness = 6616.092607147973
# Cycle 76: Best Fitness = 6562.238385954591
# Cycle 77: Best Fitness = 6543.174579510387
# Cycle 78: Best Fitness = 6500.477207315596
# Cycle 79: Best Fitness = 6471.433885943362
# Cycle 80: Best Fitness = 6471.433885943362
# Cycle 81: Best Fitness = 6459.45958063289
# Cycle 82: Best Fitness = 6459.45958063289
# Cycle 83: Best Fitness = 6428.663577057251
# Cycle 84: Best Fitness = 6411.961463757976
# Cycle 85: Best Fitness = 6406.709609294772
# Cycle 86: Best Fitness = 6382.313899512363
# Cycle 87: Best Fitness = 6370.196775022363
# Cycle 88: Best Fitness = 6368.224726724091
# Cycle 89: Best Fitness = 6362.460668828962
# Cycle 90: Best Fitness = 6350.636334311135
# Cycle 91: Best Fitness = 6350.636334311135
# Cycle 92: Best Fitness = 6339.662532786719
# Cycle 93: Best Fitness = 6281.7830250444495
# Cycle 94: Best Fitness = 6281.7830250444495
# Cycle 95: Best Fitness = 6280.826992304272
# Cycle 96: Best Fitness = 6263.013822809423
# Cycle 97: Best Fitness = 6263.013822809423
# Cycle 98: Best Fitness = 6262.331029012772
# Cycle 99: Best Fitness = 6260.540731592897
# Cycle 100: Best Fitness = 6257.048539390269
# Cycle 101: Best Fitness = 6251.300378682297
# Cycle 102: Best Fitness = 6243.014932871272
# Cycle 103: Best Fitness = 6242.166321297817
# Cycle 104: Best Fitness = 6241.496143727827
# Cycle 105: Best Fitness = 6239.624614491635
# Cycle 106: Best Fitness = 6220.815868287744
# Cycle 107: Best Fitness = 6220.815868287744
# Cycle 108: Best Fitness = 6185.5049977627295
# Cycle 109: Best Fitness = 6185.5049977627295
# Cycle 110: Best Fitness = 6168.461710059561
# Cycle 111: Best Fitness = 6168.461710059561
# Cycle 112: Best Fitness = 6164.649483760244
# Cycle 113: Best Fitness = 6144.326740705495
# Cycle 114: Best Fitness = 6143.052561882184
# Cycle 115: Best Fitness = 6143.052561882184
# Cycle 116: Best Fitness = 6143.052561882184
# Cycle 117: Best Fitness = 6143.052561882184
# Cycle 118: Best Fitness = 6143.052561882184
# Cycle 119: Best Fitness = 6143.052561882184
# Cycle 120: Best Fitness = 6137.003457331792
# Cycle 121: Best Fitness = 6137.003457331792
# Cycle 122: Best Fitness = 6125.963612336698
# Cycle 123: Best Fitness = 6125.963612336698
# Cycle 124: Best Fitness = 6125.963612336698
# Cycle 125: Best Fitness = 6119.863314553159
# Cycle 126: Best Fitness = 6111.007629915301
# Cycle 127: Best Fitness = 6111.007629915301
# Cycle 128: Best Fitness = 6111.007629915301
# Cycle 129: Best Fitness = 6086.410834938663
# Cycle 130: Best Fitness = 6086.410834938663
# Cycle 131: Best Fitness = 6085.103239269734
# Cycle 132: Best Fitness = 6085.103239269734
# Cycle 133: Best Fitness = 6053.87669506173
# Cycle 134: Best Fitness = 6053.87669506173
# Cycle 135: Best Fitness = 6051.916538885304
# Cycle 136: Best Fitness = 6050.757729932794
# Cycle 137: Best Fitness = 6050.757729932794
# Cycle 138: Best Fitness = 6050.757729932794
# Cycle 139: Best Fitness = 6050.757729932794
# Cycle 140: Best Fitness = 6044.320968707035
# Cycle 141: Best Fitness = 6040.843630620386
# Cycle 142: Best Fitness = 6040.843630620386
# Cycle 143: Best Fitness = 6035.197106330361
# Cycle 144: Best Fitness = 6035.197106330361
# Cycle 145: Best Fitness = 6035.197106330361
# Cycle 146: Best Fitness = 5994.781847126833
# Cycle 147: Best Fitness = 5969.5519755908435
# Cycle 148: Best Fitness = 5966.364200575263
# Cycle 149: Best Fitness = 5957.376683280854
# Cycle 150: Best Fitness = 5957.376683280854
# Cycle 151: Best Fitness = 5957.376683280854
# Cycle 152: Best Fitness = 5957.271628363001
# Cycle 153: Best Fitness = 5916.08073585885
# Cycle 154: Best Fitness = 5916.08073585885
# Cycle 155: Best Fitness = 5916.08073585885
# Cycle 156: Best Fitness = 5911.180595647438
# Cycle 157: Best Fitness = 5905.9687268385205
# Cycle 158: Best Fitness = 5862.202377160505
# Cycle 159: Best Fitness = 5850.545522911014
# Cycle 160: Best Fitness = 5850.545522911014
# Cycle 161: Best Fitness = 5847.355882384531
# Cycle 162: Best Fitness = 5847.355882384531
# Cycle 163: Best Fitness = 5847.29796336021
# Cycle 164: Best Fitness = 5820.642639706357
# Cycle 165: Best Fitness = 5817.8888348240125
# Cycle 166: Best Fitness = 5810.958767847623
# Cycle 167: Best Fitness = 5804.195383446879
# Cycle 168: Best Fitness = 5796.255685785322
# Cycle 169: Best Fitness = 5768.836316729821
# Cycle 170: Best Fitness = 5768.836316729821
# Cycle 171: Best Fitness = 5768.836316729821
# Cycle 172: Best Fitness = 5756.690261881493
# Cycle 173: Best Fitness = 5723.841831320048
# Cycle 174: Best Fitness = 5723.841831320048
# Cycle 175: Best Fitness = 5716.817236782777
# Cycle 176: Best Fitness = 5713.240658693643
# Cycle 177: Best Fitness = 5700.930916074683
# Cycle 178: Best Fitness = 5696.028802886251
# Cycle 179: Best Fitness = 5696.028802886251
# Cycle 180: Best Fitness = 5696.028802886251
# Cycle 181: Best Fitness = 5690.147049526765
# Cycle 182: Best Fitness = 5683.593554109487
# Cycle 183: Best Fitness = 5673.726579324855
# Cycle 184: Best Fitness = 5617.97685001338
# Cycle 185: Best Fitness = 5612.010629867354
# Cycle 186: Best Fitness = 5612.010629867354
# Cycle 187: Best Fitness = 5595.000945258034
# Cycle 188: Best Fitness = 5595.000945258034
# Cycle 189: Best Fitness = 5595.000945258034
# Cycle 190: Best Fitness = 5587.236916934633
# Cycle 191: Best Fitness = 5584.91968726885
# Cycle 192: Best Fitness = 5552.374334609101
# Cycle 193: Best Fitness = 5544.711509527641
# Cycle 194: Best Fitness = 5544.711509527641
# Cycle 195: Best Fitness = 5508.415873797232
# Cycle 196: Best Fitness = 5508.415873797232
# Cycle 197: Best Fitness = 5508.411920841012
# Cycle 198: Best Fitness = 5502.126004609877
# Cycle 199: Best Fitness = 5502.126004609877
# Cycle 200: Best Fitness = 5488.89983858283
# Cycle 201: Best Fitness = 5480.838345463406
# Cycle 202: Best Fitness = 5480.838345463406
# Cycle 203: Best Fitness = 5480.838345463406
# Cycle 204: Best Fitness = 5456.449375220574
# Cycle 205: Best Fitness = 5452.82443089807
# Cycle 206: Best Fitness = 5452.82443089807
# Cycle 207: Best Fitness = 5450.464587257344
# Cycle 208: Best Fitness = 5450.464587257344
# Cycle 209: Best Fitness = 5437.78436461934
# Cycle 210: Best Fitness = 5389.969409584918
# Cycle 211: Best Fitness = 5378.521075803139
# Cycle 212: Best Fitness = 5365.050823866573
# Cycle 213: Best Fitness = 5365.050823866573
# Cycle 214: Best Fitness = 5363.851274804545
# Cycle 215: Best Fitness = 5355.023101959333
# Cycle 216: Best Fitness = 5355.023101959333
# Cycle 217: Best Fitness = 5347.237865646204
# Cycle 218: Best Fitness = 5347.237865646204
# Cycle 219: Best Fitness = 5338.151458112474
# Cycle 220: Best Fitness = 5335.0816003313175
# Cycle 221: Best Fitness = 5329.572808175131
# Cycle 222: Best Fitness = 5329.572808175131
# Cycle 223: Best Fitness = 5312.5368265323905
# Cycle 224: Best Fitness = 5312.5368265323905
# Cycle 225: Best Fitness = 5303.615318982284
# Cycle 226: Best Fitness = 5300.91297816373
# Cycle 227: Best Fitness = 5288.346607969746
# Cycle 228: Best Fitness = 5288.346607969746
# Cycle 229: Best Fitness = 5288.346607969746
# Cycle 230: Best Fitness = 5288.066472478322
# Cycle 231: Best Fitness = 5285.40081194477
# Cycle 232: Best Fitness = 5253.129054141047
# Cycle 233: Best Fitness = 5252.656248672385
# Cycle 234: Best Fitness = 5252.656248672385
# Cycle 235: Best Fitness = 5252.2460798384
# Cycle 236: Best Fitness = 5226.2424427436945
# Cycle 237: Best Fitness = 5225.975084451586
# Cycle 238: Best Fitness = 5225.975084451586
# Cycle 239: Best Fitness = 5215.898911088152
# Cycle 240: Best Fitness = 5215.898911088152
# Cycle 241: Best Fitness = 5201.511443526118
# Cycle 242: Best Fitness = 5188.048248868806
# Cycle 243: Best Fitness = 5188.048248868806
# Cycle 244: Best Fitness = 5188.048248868806
# Cycle 245: Best Fitness = 5178.370989212354
# Cycle 246: Best Fitness = 5178.1213122090885
# Cycle 247: Best Fitness = 5178.1213122090885
# Cycle 248: Best Fitness = 5178.1213122090885
# Cycle 249: Best Fitness = 5178.1213122090885
# Cycle 250: Best Fitness = 5178.1213122090885
# Cycle 251: Best Fitness = 5158.3668510186335
# Cycle 252: Best Fitness = 5158.3668510186335
# Cycle 253: Best Fitness = 5158.3668510186335
# Cycle 254: Best Fitness = 5148.458913208727
# Cycle 255: Best Fitness = 5148.255900148586
# Cycle 256: Best Fitness = 5140.770788722186
# Cycle 257: Best Fitness = 5138.15852499211
# Cycle 258: Best Fitness = 5138.15852499211
# Cycle 259: Best Fitness = 5092.631758764961
# Cycle 260: Best Fitness = 5092.631758764961
# Cycle 261: Best Fitness = 5086.7382842552015
# Cycle 262: Best Fitness = 5084.290234412226
# Cycle 263: Best Fitness = 5084.290234412226
# Cycle 264: Best Fitness = 5075.893703018905
# Cycle 265: Best Fitness = 5075.893703018905
# Cycle 266: Best Fitness = 5069.22282701553
# Cycle 267: Best Fitness = 5060.814744113429
# Cycle 268: Best Fitness = 5060.814744113429
# Cycle 269: Best Fitness = 5047.098562944142
# Cycle 270: Best Fitness = 5028.982613165613
# Cycle 271: Best Fitness = 5028.982613165613
# Cycle 272: Best Fitness = 5028.982613165613
# Cycle 273: Best Fitness = 5026.052131814959
# Cycle 274: Best Fitness = 5026.052131814959
# Cycle 275: Best Fitness = 5026.052131814959
# Cycle 276: Best Fitness = 5026.052131814959
# Cycle 277: Best Fitness = 5026.052131814959
# Cycle 278: Best Fitness = 5013.206132600742
# Cycle 279: Best Fitness = 5010.98325675146
# Cycle 280: Best Fitness = 5002.697067268124
# Cycle 281: Best Fitness = 4992.336196421293
# Cycle 282: Best Fitness = 4992.336196421293
# Cycle 283: Best Fitness = 4992.336196421293
# Cycle 284: Best Fitness = 4992.336196421293
# Cycle 285: Best Fitness = 4988.758141101935
# Cycle 286: Best Fitness = 4988.758141101935
# Cycle 287: Best Fitness = 4988.240033981777
# Cycle 288: Best Fitness = 4988.240033981777
# Cycle 289: Best Fitness = 4988.240033981777
# Cycle 290: Best Fitness = 4976.7560710957305
# Cycle 291: Best Fitness = 4976.7560710957305
# Cycle 292: Best Fitness = 4976.7560710957305
# Cycle 293: Best Fitness = 4976.7560710957305
# Cycle 294: Best Fitness = 4971.293388494076
# Cycle 295: Best Fitness = 4968.440541865453
# Cycle 296: Best Fitness = 4959.579109449085
# Cycle 297: Best Fitness = 4955.519436520888
# Cycle 298: Best Fitness = 4954.275534955357
# Cycle 299: Best Fitness = 4954.275534955357
# Cycle 300: Best Fitness = 4933.487669370719
# Cycle 301: Best Fitness = 4928.7373477835945
# Cycle 302: Best Fitness = 4901.07464771973
# Cycle 303: Best Fitness = 4901.029401631564
# Cycle 304: Best Fitness = 4901.029401631564
# Cycle 305: Best Fitness = 4895.923351079218
# Cycle 306: Best Fitness = 4895.923351079218
# Cycle 307: Best Fitness = 4894.774139993677
# Cycle 308: Best Fitness = 4894.774139993677
# Cycle 309: Best Fitness = 4894.774139993677
# Cycle 310: Best Fitness = 4888.222878374727
# Cycle 311: Best Fitness = 4876.691120994048
# Cycle 312: Best Fitness = 4858.231173913486
# Cycle 313: Best Fitness = 4856.7911739223855
# Cycle 314: Best Fitness = 4856.673084587934
# Cycle 315: Best Fitness = 4856.673084587934
# Cycle 316: Best Fitness = 4856.673084587934
# Cycle 317: Best Fitness = 4856.673084587934
# Cycle 318: Best Fitness = 4856.673084587934
# Cycle 319: Best Fitness = 4856.382459113869
# Cycle 320: Best Fitness = 4855.042276598149
# Cycle 321: Best Fitness = 4855.042276598149
# Cycle 322: Best Fitness = 4854.915335569525
# Cycle 323: Best Fitness = 4854.604127020064
# Cycle 324: Best Fitness = 4851.873487086605
# Cycle 325: Best Fitness = 4851.873487086605
# Cycle 326: Best Fitness = 4851.83183109803
# Cycle 327: Best Fitness = 4846.033465924417
# Cycle 328: Best Fitness = 4846.033465924417
# Cycle 329: Best Fitness = 4846.033465924417
# Cycle 330: Best Fitness = 4836.772811976741
# Cycle 331: Best Fitness = 4836.772811976741
# Cycle 332: Best Fitness = 4835.192000706607
# Cycle 333: Best Fitness = 4835.192000706607
# Cycle 334: Best Fitness = 4799.086385693576
# Cycle 335: Best Fitness = 4799.086385693576
# Cycle 336: Best Fitness = 4799.086385693576
# Cycle 337: Best Fitness = 4776.437433752048
# Cycle 338: Best Fitness = 4776.437433752048
# Cycle 339: Best Fitness = 4775.694712783058
# Cycle 340: Best Fitness = 4775.694712783058
# Cycle 341: Best Fitness = 4775.694712783058
# Cycle 342: Best Fitness = 4775.694712783058
# Cycle 343: Best Fitness = 4775.694712783058
# Cycle 344: Best Fitness = 4775.694712783058
# Cycle 345: Best Fitness = 4775.694712783058
# Cycle 346: Best Fitness = 4766.415211472628
# Cycle 347: Best Fitness = 4763.903594930128
# Cycle 348: Best Fitness = 4763.903594930128
# Cycle 349: Best Fitness = 4763.903594930128
# Cycle 350: Best Fitness = 4763.903594930128
# Cycle 351: Best Fitness = 4763.903594930128
# Cycle 352: Best Fitness = 4763.903594930128
# Cycle 353: Best Fitness = 4763.903594930128
# Cycle 354: Best Fitness = 4751.584037326513
# Cycle 355: Best Fitness = 4751.584037326513
# Cycle 356: Best Fitness = 4751.584037326513
# Cycle 357: Best Fitness = 4727.685190602862
# Cycle 358: Best Fitness = 4713.514612045892
# Cycle 359: Best Fitness = 4713.514612045892
# Cycle 360: Best Fitness = 4713.514612045892
# Cycle 361: Best Fitness = 4713.514612045892
# Cycle 362: Best Fitness = 4709.879673683966
# Cycle 363: Best Fitness = 4705.32947621349
# Cycle 364: Best Fitness = 4703.033149401361
# Cycle 365: Best Fitness = 4702.884169228564
# Cycle 366: Best Fitness = 4692.205349996746
# Cycle 367: Best Fitness = 4692.205349996746
# Cycle 368: Best Fitness = 4692.205349996746
# Cycle 369: Best Fitness = 4692.205349996746
# Cycle 370: Best Fitness = 4692.205349996746
# Cycle 371: Best Fitness = 4680.586659838522
# Cycle 372: Best Fitness = 4680.243020100164
# Cycle 373: Best Fitness = 4680.243020100164
# Cycle 374: Best Fitness = 4680.243020100164
# Cycle 375: Best Fitness = 4680.243020100164
# Cycle 376: Best Fitness = 4680.243020100164
# Cycle 377: Best Fitness = 4680.243020100164
# Cycle 378: Best Fitness = 4680.243020100164
# Cycle 379: Best Fitness = 4680.243020100164
# Cycle 380: Best Fitness = 4667.72789162514
# Cycle 381: Best Fitness = 4656.358834111481
# Cycle 382: Best Fitness = 4656.030423736664
# Cycle 383: Best Fitness = 4656.030423736664
# Cycle 384: Best Fitness = 4649.837070496454
# Cycle 385: Best Fitness = 4649.837070496454
# Cycle 386: Best Fitness = 4649.837070496454
# Cycle 387: Best Fitness = 4649.837070496454
# Cycle 388: Best Fitness = 4649.837070496454
# Cycle 389: Best Fitness = 4644.678330739439
# Cycle 390: Best Fitness = 4644.678330739439
# Cycle 391: Best Fitness = 4644.678330739439
# Cycle 392: Best Fitness = 4641.79373055826
# Cycle 393: Best Fitness = 4641.79373055826
# Cycle 394: Best Fitness = 4641.79373055826
# Cycle 395: Best Fitness = 4637.058054699844
# Cycle 396: Best Fitness = 4637.058054699844
# Cycle 397: Best Fitness = 4637.058054699844
# Cycle 398: Best Fitness = 4637.058054699844
# Cycle 399: Best Fitness = 4635.769591782807
# Cycle 400: Best Fitness = 4635.769591782807
# Cycle 401: Best Fitness = 4626.702094535058
# Cycle 402: Best Fitness = 4607.740123485372
# Cycle 403: Best Fitness = 4600.532569631998
# Cycle 404: Best Fitness = 4600.532569631998
# Cycle 405: Best Fitness = 4600.532569631998
# Cycle 406: Best Fitness = 4600.532569631998
# Cycle 407: Best Fitness = 4581.396536099669
# Cycle 408: Best Fitness = 4581.396536099669
# Cycle 409: Best Fitness = 4568.1462646724185
# Cycle 410: Best Fitness = 4568.1462646724185
# Cycle 411: Best Fitness = 4566.378578264771
# Cycle 412: Best Fitness = 4563.23269684588
# Cycle 413: Best Fitness = 4563.23269684588
# Cycle 414: Best Fitness = 4563.23269684588
# Cycle 415: Best Fitness = 4563.23269684588
# Cycle 416: Best Fitness = 4563.23269684588
# Cycle 417: Best Fitness = 4563.23269684588
# Cycle 418: Best Fitness = 4561.689936063325
# Cycle 419: Best Fitness = 4561.689936063325
# Cycle 420: Best Fitness = 4561.689936063325
# Cycle 421: Best Fitness = 4561.689936063325
# Cycle 422: Best Fitness = 4561.689936063325
# Cycle 423: Best Fitness = 4555.694341688404
# Cycle 424: Best Fitness = 4555.694341688404
# Cycle 425: Best Fitness = 4555.694341688404
# Cycle 426: Best Fitness = 4555.694341688404
# Cycle 427: Best Fitness = 4554.694766166239
# Cycle 428: Best Fitness = 4554.694766166239
# Cycle 429: Best Fitness = 4547.17831499355
# Cycle 430: Best Fitness = 4547.17831499355
# Cycle 431: Best Fitness = 4540.799656138144
# Cycle 432: Best Fitness = 4540.264387963263
# Cycle 433: Best Fitness = 4539.113209447709
# Cycle 434: Best Fitness = 4539.113209447709
# Cycle 435: Best Fitness = 4539.113209447709
# Cycle 436: Best Fitness = 4539.113209447709
# Cycle 437: Best Fitness = 4538.52787863929
# Cycle 438: Best Fitness = 4527.566610169347
# Cycle 439: Best Fitness = 4525.388464584474
# Cycle 440: Best Fitness = 4515.045291117054
# Cycle 441: Best Fitness = 4515.045291117054
# Cycle 442: Best Fitness = 4515.045291117054
# Cycle 443: Best Fitness = 4515.045291117054
# Cycle 444: Best Fitness = 4505.282569572076
# Cycle 445: Best Fitness = 4505.282569572076
# Cycle 446: Best Fitness = 4505.282569572076
# Cycle 447: Best Fitness = 4505.282569572076
# Cycle 448: Best Fitness = 4505.282569572076
# Cycle 449: Best Fitness = 4505.282569572076
# Cycle 450: Best Fitness = 4480.8943850288015
# Cycle 451: Best Fitness = 4480.8943850288015
# Cycle 452: Best Fitness = 4480.8943850288015
# Cycle 453: Best Fitness = 4480.8943850288015
# Cycle 454: Best Fitness = 4480.8943850288015
# Cycle 455: Best Fitness = 4480.8943850288015
# Cycle 456: Best Fitness = 4480.8943850288015
# Cycle 457: Best Fitness = 4480.8943850288015
# Cycle 458: Best Fitness = 4480.685033851623
# Cycle 459: Best Fitness = 4480.685033851623
# Cycle 460: Best Fitness = 4480.685033851623
# Cycle 461: Best Fitness = 4474.922478312497
# Cycle 462: Best Fitness = 4471.776081912941
# Cycle 463: Best Fitness = 4471.776081912941
# Cycle 464: Best Fitness = 4453.732527968897
# Cycle 465: Best Fitness = 4453.732527968897
# Cycle 466: Best Fitness = 4446.259743473413
# Cycle 467: Best Fitness = 4446.259743473413
# Cycle 468: Best Fitness = 4443.113544074764
# Cycle 469: Best Fitness = 4443.113544074764
# Cycle 470: Best Fitness = 4433.700738929045
# Cycle 471: Best Fitness = 4433.700738929045
# Cycle 472: Best Fitness = 4432.337082368939
# Cycle 473: Best Fitness = 4431.097862560553
# Cycle 474: Best Fitness = 4430.441685004969
# Cycle 475: Best Fitness = 4430.441685004969
# Cycle 476: Best Fitness = 4419.957086788192
# Cycle 477: Best Fitness = 4419.957086788192
# Cycle 478: Best Fitness = 4419.957086788192
# Cycle 479: Best Fitness = 4419.957086788192
# Cycle 480: Best Fitness = 4419.957086788192
# Cycle 481: Best Fitness = 4419.694812428043
# Cycle 482: Best Fitness = 4419.694812428043
# Cycle 483: Best Fitness = 4419.694812428043
# Cycle 484: Best Fitness = 4419.694812428043
# Cycle 485: Best Fitness = 4419.694812428043
# Cycle 486: Best Fitness = 4419.694812428043
# Cycle 487: Best Fitness = 4419.694812428043
# Cycle 488: Best Fitness = 4419.694812428043
# Cycle 489: Best Fitness = 4419.694812428043
# Cycle 490: Best Fitness = 4411.822177698281
# Cycle 491: Best Fitness = 4411.822177698281
# Cycle 492: Best Fitness = 4411.822177698281
# Cycle 493: Best Fitness = 4411.822177698281
# Cycle 494: Best Fitness = 4401.269899587258
# Cycle 495: Best Fitness = 4400.495350630123
# Cycle 496: Best Fitness = 4400.495350630123
# Cycle 497: Best Fitness = 4400.494034643225
# Cycle 498: Best Fitness = 4396.847667464403
# Cycle 499: Best Fitness = 4396.847667464403
# Cycle 500: Best Fitness = 4396.847667464403
# Cycle 501: Best Fitness = 4396.464607218635
# Cycle 502: Best Fitness = 4396.464607218635
# Cycle 503: Best Fitness = 4395.501115224597
# Cycle 504: Best Fitness = 4390.957387378786
# Cycle 505: Best Fitness = 4390.957387378786
# Cycle 506: Best Fitness = 4390.957387378786
# Cycle 507: Best Fitness = 4390.957387378786
# Cycle 508: Best Fitness = 4390.957387378786
# Cycle 509: Best Fitness = 4390.957387378786
# Cycle 510: Best Fitness = 4390.957387378786
# Cycle 511: Best Fitness = 4388.42088623193
# Cycle 512: Best Fitness = 4383.647965925562
# Cycle 513: Best Fitness = 4379.534088107038
# Cycle 514: Best Fitness = 4367.874978671157
# Cycle 515: Best Fitness = 4367.0329407365525
# Cycle 516: Best Fitness = 4367.0329407365525
# Cycle 517: Best Fitness = 4367.0329407365525
# Cycle 518: Best Fitness = 4367.0329407365525
# Cycle 519: Best Fitness = 4367.0329407365525
# Cycle 520: Best Fitness = 4363.015247959533
# Cycle 521: Best Fitness = 4336.648736818021
# Cycle 522: Best Fitness = 4335.780616233204
# Cycle 523: Best Fitness = 4319.5374773757985
# Cycle 524: Best Fitness = 4319.5374773757985
# Cycle 525: Best Fitness = 4316.998291963531
# Cycle 526: Best Fitness = 4316.998291963531
# Cycle 527: Best Fitness = 4316.998291963531
# Cycle 528: Best Fitness = 4315.025685413065
# Cycle 529: Best Fitness = 4315.025685413065
# Cycle 530: Best Fitness = 4314.852093579962
# Cycle 531: Best Fitness = 4314.852093579962
# Cycle 532: Best Fitness = 4280.329298753132
# Cycle 533: Best Fitness = 4280.329298753132
# Cycle 534: Best Fitness = 4267.128724563237
# Cycle 535: Best Fitness = 4267.128724563237
# Cycle 536: Best Fitness = 4267.128724563237
# Cycle 537: Best Fitness = 4266.478884545078
# Cycle 538: Best Fitness = 4245.92271817648
# Cycle 539: Best Fitness = 4245.92271817648
# Cycle 540: Best Fitness = 4222.597225316169
# Cycle 541: Best Fitness = 4209.919784047099
# Cycle 542: Best Fitness = 4209.919784047099
# Cycle 543: Best Fitness = 4209.919784047099
# Cycle 544: Best Fitness = 4209.919784047099
# Cycle 545: Best Fitness = 4209.919784047099
# Cycle 546: Best Fitness = 4209.919784047099
# Cycle 547: Best Fitness = 4209.919784047099
# Cycle 548: Best Fitness = 4209.919784047099
# Cycle 549: Best Fitness = 4209.919784047099
# Cycle 550: Best Fitness = 4183.8189715079725
# Cycle 551: Best Fitness = 4183.8189715079725
# Cycle 552: Best Fitness = 4174.125957551263
# Cycle 553: Best Fitness = 4174.125957551263
# Cycle 554: Best Fitness = 4174.125957551263
# Cycle 555: Best Fitness = 4174.125957551263
# Cycle 556: Best Fitness = 4174.125957551263
# Cycle 557: Best Fitness = 4172.014938944401
# Cycle 558: Best Fitness = 4172.014938944401
# Cycle 559: Best Fitness = 4172.014938944401
# Cycle 560: Best Fitness = 4166.042316336562
# Cycle 561: Best Fitness = 4166.042316336562
# Cycle 562: Best Fitness = 4166.042316336562
# Cycle 563: Best Fitness = 4166.042316336562
# Cycle 564: Best Fitness = 4153.871372642767
# Cycle 565: Best Fitness = 4153.871372642767
# Cycle 566: Best Fitness = 4153.871372642767
# Cycle 567: Best Fitness = 4153.871372642767
# Cycle 568: Best Fitness = 4153.871372642767
# Cycle 569: Best Fitness = 4153.871372642767
# Cycle 570: Best Fitness = 4152.260491379062
# Cycle 571: Best Fitness = 4152.260491379062
# Cycle 572: Best Fitness = 4142.888912464118
# Cycle 573: Best Fitness = 4142.888912464118
# Cycle 574: Best Fitness = 4142.888912464118
# Cycle 575: Best Fitness = 4142.888912464118
# Cycle 576: Best Fitness = 4135.483239212792
# Cycle 577: Best Fitness = 4135.483239212792
# Cycle 578: Best Fitness = 4135.483239212792
# Cycle 579: Best Fitness = 4135.483239212792
# Cycle 580: Best Fitness = 4135.480265699902
# Cycle 581: Best Fitness = 4135.480265699902
# Cycle 582: Best Fitness = 4126.445537538903
# Cycle 583: Best Fitness = 4126.445537538903
# Cycle 584: Best Fitness = 4126.445537538903
# Cycle 585: Best Fitness = 4126.445537538903
# Cycle 586: Best Fitness = 4126.445537538903
# Cycle 587: Best Fitness = 4126.445537538903
# Cycle 588: Best Fitness = 4124.372911484934
# Cycle 589: Best Fitness = 4124.372911484934
# Cycle 590: Best Fitness = 4124.372911484934
# Cycle 591: Best Fitness = 4124.372911484934
# Cycle 592: Best Fitness = 4124.372911484934
# Cycle 593: Best Fitness = 4124.372911484934
# Cycle 594: Best Fitness = 4120.673376041053
# Cycle 595: Best Fitness = 4120.673376041053
# Cycle 596: Best Fitness = 4120.673376041053
# Cycle 597: Best Fitness = 4120.673376041053
# Cycle 598: Best Fitness = 4117.121689319426
# Cycle 599: Best Fitness = 4117.121689319426
# Cycle 600: Best Fitness = 4117.121689319426
# Cycle 601: Best Fitness = 4117.121689319426
# Cycle 602: Best Fitness = 4117.121689319426
# Cycle 603: Best Fitness = 4115.678202990566
# Cycle 604: Best Fitness = 4115.678202990566
# Cycle 605: Best Fitness = 4115.678202990566
# Cycle 606: Best Fitness = 4115.678202990566
# Cycle 607: Best Fitness = 4111.631241505057
# Cycle 608: Best Fitness = 4109.838586336256
# Cycle 609: Best Fitness = 4109.838586336256
# Cycle 610: Best Fitness = 4109.838586336256
# Cycle 611: Best Fitness = 4109.838586336256
# Cycle 612: Best Fitness = 4109.838586336256
# Cycle 613: Best Fitness = 4109.838586336256
# Cycle 614: Best Fitness = 4109.838586336256
# Cycle 615: Best Fitness = 4104.497044806233
# Cycle 616: Best Fitness = 4104.497044806233
# Cycle 617: Best Fitness = 4091.6681325299687
# Cycle 618: Best Fitness = 4091.6681325299687
# Cycle 619: Best Fitness = 4091.6681325299687
# Cycle 620: Best Fitness = 4082.1833721066027
# Cycle 621: Best Fitness = 4082.1833721066027
# Cycle 622: Best Fitness = 4082.1833721066027
# Cycle 623: Best Fitness = 4082.1833721066027
# Cycle 624: Best Fitness = 4082.1833721066027
# Cycle 625: Best Fitness = 4077.6125063958298
# Cycle 626: Best Fitness = 4066.7604757054987
# Cycle 627: Best Fitness = 4066.7604757054987
# Cycle 628: Best Fitness = 4066.7604757054987
# Cycle 629: Best Fitness = 4066.7604757054987
# Cycle 630: Best Fitness = 4066.7604757054987
# Cycle 631: Best Fitness = 4066.7604757054987
# Cycle 632: Best Fitness = 4066.7604757054987
# Cycle 633: Best Fitness = 4066.7604757054987
# Cycle 634: Best Fitness = 4066.7604757054987
# Cycle 635: Best Fitness = 4066.7604757054987
# Cycle 636: Best Fitness = 4066.7604757054987
# Cycle 637: Best Fitness = 4056.4900098469034
# Cycle 638: Best Fitness = 4056.4900098469034
# Cycle 639: Best Fitness = 4056.4900098469034
# Cycle 640: Best Fitness = 4056.4900098469034
# Cycle 641: Best Fitness = 4056.4900098469034
# Cycle 642: Best Fitness = 4056.4900098469034
# Cycle 643: Best Fitness = 4054.799962799483
# Cycle 644: Best Fitness = 4052.152850526285
# Cycle 645: Best Fitness = 4052.152850526285
# Cycle 646: Best Fitness = 4052.152850526285
# Cycle 647: Best Fitness = 4042.198377676598
# Cycle 648: Best Fitness = 4041.9921337023316
# Cycle 649: Best Fitness = 4041.9921337023316
# Cycle 650: Best Fitness = 4041.9921337023316
# Cycle 651: Best Fitness = 4021.2882308832804
# Cycle 652: Best Fitness = 4021.2882308832804
# Cycle 653: Best Fitness = 4021.2882308832804
# Cycle 654: Best Fitness = 4021.2882308832804
# Cycle 655: Best Fitness = 4020.504023004244
# Cycle 656: Best Fitness = 4020.504023004244
# Cycle 657: Best Fitness = 4020.504023004244
# Cycle 658: Best Fitness = 4020.504023004244
# Cycle 659: Best Fitness = 4014.863707584168
# Cycle 660: Best Fitness = 4014.863707584168
# Cycle 661: Best Fitness = 4014.863707584168
# Cycle 662: Best Fitness = 4014.863707584168
# Cycle 663: Best Fitness = 4005.102939056145
# Cycle 664: Best Fitness = 4005.102939056145
# Cycle 665: Best Fitness = 4005.102939056145
# Cycle 666: Best Fitness = 3993.7475814591107
# Cycle 667: Best Fitness = 3993.7475814591107
# Cycle 668: Best Fitness = 3993.7475814591107
# Cycle 669: Best Fitness = 3993.7475814591107
# Cycle 670: Best Fitness = 3993.7475814591107
# Cycle 671: Best Fitness = 3990.3858585712987
# Cycle 672: Best Fitness = 3990.3858585712987
# Cycle 673: Best Fitness = 3985.5793488729287
# Cycle 674: Best Fitness = 3985.5793488729287
# Cycle 675: Best Fitness = 3985.5793488729287
# Cycle 676: Best Fitness = 3985.5793488729287
# Cycle 677: Best Fitness = 3985.5793488729287
# Cycle 678: Best Fitness = 3985.5793488729287
# Cycle 679: Best Fitness = 3985.5793488729287
# Cycle 680: Best Fitness = 3971.981369373764
# Cycle 681: Best Fitness = 3971.981369373764
# Cycle 682: Best Fitness = 3971.981369373764
# Cycle 683: Best Fitness = 3969.644894412764
# Cycle 684: Best Fitness = 3969.644894412764
# Cycle 685: Best Fitness = 3953.137068727141
# Cycle 686: Best Fitness = 3953.137068727141
# Cycle 687: Best Fitness = 3953.137068727141
# Cycle 688: Best Fitness = 3953.137068727141
# Cycle 689: Best Fitness = 3953.137068727141
# Cycle 690: Best Fitness = 3953.137068727141
# Cycle 691: Best Fitness = 3946.347978607957
# Cycle 692: Best Fitness = 3943.1111106520048
# Cycle 693: Best Fitness = 3942.878024082008
# Cycle 694: Best Fitness = 3942.878024082008
# Cycle 695: Best Fitness = 3942.878024082008
# Cycle 696: Best Fitness = 3942.878024082008
# Cycle 697: Best Fitness = 3942.878024082008
# Cycle 698: Best Fitness = 3942.8713807140757
# Cycle 699: Best Fitness = 3942.8713807140757
# Cycle 700: Best Fitness = 3942.8713807140757
# Cycle 701: Best Fitness = 3942.8713807140757
# Cycle 702: Best Fitness = 3939.56043605629
# Cycle 703: Best Fitness = 3939.56043605629
# Cycle 704: Best Fitness = 3939.56043605629
# Cycle 705: Best Fitness = 3916.567802679643
# Cycle 706: Best Fitness = 3912.1031244335013
# Cycle 707: Best Fitness = 3910.191156052728
# Cycle 708: Best Fitness = 3908.480988221121
# Cycle 709: Best Fitness = 3908.480988221121
# Cycle 710: Best Fitness = 3908.480988221121
# Cycle 711: Best Fitness = 3908.480988221121
# Cycle 712: Best Fitness = 3908.480988221121
# Cycle 713: Best Fitness = 3905.763699293294
# Cycle 714: Best Fitness = 3905.763699293294
# Cycle 715: Best Fitness = 3903.988753267603
# Cycle 716: Best Fitness = 3893.8879285099742
# Cycle 717: Best Fitness = 3893.8879285099742
# Cycle 718: Best Fitness = 3893.8879285099742
# Cycle 719: Best Fitness = 3893.8879285099742
# Cycle 720: Best Fitness = 3893.8879285099742
# Cycle 721: Best Fitness = 3893.8879285099742
# Cycle 722: Best Fitness = 3892.849685013748
# Cycle 723: Best Fitness = 3888.8970902311166
# Cycle 724: Best Fitness = 3888.8970902311166
# Cycle 725: Best Fitness = 3888.8970902311166
# Cycle 726: Best Fitness = 3888.8970902311166
# Cycle 727: Best Fitness = 3888.8970902311166
# Cycle 728: Best Fitness = 3886.1403969440294
# Cycle 729: Best Fitness = 3886.1403969440294
# Cycle 730: Best Fitness = 3885.6968564755734
# Cycle 731: Best Fitness = 3885.6968564755734
# Cycle 732: Best Fitness = 3871.918629591477
# Cycle 733: Best Fitness = 3871.918629591477
# Cycle 734: Best Fitness = 3871.918629591477
# Cycle 735: Best Fitness = 3871.918629591477
# Cycle 736: Best Fitness = 3871.918629591477
# Cycle 737: Best Fitness = 3871.200618207168
# Cycle 738: Best Fitness = 3871.200618207168
# Cycle 739: Best Fitness = 3871.200618207168
# Cycle 740: Best Fitness = 3871.200618207168
# Cycle 741: Best Fitness = 3871.200618207168
# Cycle 742: Best Fitness = 3869.5280022825586
# Cycle 743: Best Fitness = 3869.5280022825586
# Cycle 744: Best Fitness = 3869.5280022825586
# Cycle 745: Best Fitness = 3869.5280022825586
# Cycle 746: Best Fitness = 3869.5280022825586
# Cycle 747: Best Fitness = 3869.5280022825586
# Cycle 748: Best Fitness = 3869.5280022825586
# Cycle 749: Best Fitness = 3861.7078870545542
# Cycle 750: Best Fitness = 3860.186140926124
# Cycle 751: Best Fitness = 3860.186140926124
# Cycle 752: Best Fitness = 3859.6579821407613
# Cycle 753: Best Fitness = 3859.6579821407613
# Cycle 754: Best Fitness = 3859.6579821407613
# Cycle 755: Best Fitness = 3859.6579821407613
# Cycle 756: Best Fitness = 3859.6579821407613
# Cycle 757: Best Fitness = 3858.9465009352016
# Cycle 758: Best Fitness = 3858.9465009352016
# Cycle 759: Best Fitness = 3858.944376390892
# Cycle 760: Best Fitness = 3858.944376390892
# Cycle 761: Best Fitness = 3858.944376390892
# Cycle 762: Best Fitness = 3856.3367629441564
# Cycle 763: Best Fitness = 3850.9833972591023
# Cycle 764: Best Fitness = 3850.9833972591023
# Cycle 765: Best Fitness = 3850.9833972591023
# Cycle 766: Best Fitness = 3850.9833972591023
# Cycle 767: Best Fitness = 3850.9833972591023
# Cycle 768: Best Fitness = 3850.9833972591023
# Cycle 769: Best Fitness = 3850.9833972591023
# Cycle 770: Best Fitness = 3850.5004611917298
# Cycle 771: Best Fitness = 3850.5004611917298
# Cycle 772: Best Fitness = 3850.5004611917298
# Cycle 773: Best Fitness = 3850.5004611917298
# Cycle 774: Best Fitness = 3850.5004611917298
# Cycle 775: Best Fitness = 3836.4172057537917
# Cycle 776: Best Fitness = 3836.4172057537917
# Cycle 777: Best Fitness = 3836.4172057537917
# Cycle 778: Best Fitness = 3821.9615713437715
# Cycle 779: Best Fitness = 3821.9615713437715
# Cycle 780: Best Fitness = 3821.9615713437715
# Cycle 781: Best Fitness = 3821.9615713437715
# Cycle 782: Best Fitness = 3821.9615713437715
# Cycle 783: Best Fitness = 3821.9615713437715
# Cycle 784: Best Fitness = 3821.9615713437715
# Cycle 785: Best Fitness = 3821.9615713437715
# Cycle 786: Best Fitness = 3819.706537041565
# Cycle 787: Best Fitness = 3819.706537041565
# Cycle 788: Best Fitness = 3819.706537041565
# Cycle 789: Best Fitness = 3819.706537041565
# Cycle 790: Best Fitness = 3819.706537041565
# Cycle 791: Best Fitness = 3819.706537041565
# Cycle 792: Best Fitness = 3819.706537041565
# Cycle 793: Best Fitness = 3819.706537041565
# Cycle 794: Best Fitness = 3819.706537041565
# Cycle 795: Best Fitness = 3819.2487258721367
# Cycle 796: Best Fitness = 3819.2487258721367
# Cycle 797: Best Fitness = 3816.4049909114933
# Cycle 798: Best Fitness = 3816.4049909114933
# Cycle 799: Best Fitness = 3816.4049909114933
# Cycle 800: Best Fitness = 3815.5446324626478
# Cycle 801: Best Fitness = 3815.339023246856
# Cycle 802: Best Fitness = 3815.339023246856
# Cycle 803: Best Fitness = 3812.3912239196156
# Cycle 804: Best Fitness = 3806.715385989818
# Cycle 805: Best Fitness = 3803.289936197411
# Cycle 806: Best Fitness = 3803.289936197411
# Cycle 807: Best Fitness = 3803.289936197411
# Cycle 808: Best Fitness = 3799.1834754667257
# Cycle 809: Best Fitness = 3799.1834754667257
# Cycle 810: Best Fitness = 3799.1834754667257
# Cycle 811: Best Fitness = 3793.481433279844
# Cycle 812: Best Fitness = 3793.481433279844
# Cycle 813: Best Fitness = 3793.481433279844
# Cycle 814: Best Fitness = 3793.1477879451436
# Cycle 815: Best Fitness = 3793.1477879451436
# Cycle 816: Best Fitness = 3793.1477879451436
# Cycle 817: Best Fitness = 3764.947592086093
# Cycle 818: Best Fitness = 3762.4842273006698
# Cycle 819: Best Fitness = 3757.870641829796
# Cycle 820: Best Fitness = 3757.870641829796
# Cycle 821: Best Fitness = 3757.870641829796
# Cycle 822: Best Fitness = 3757.870641829796
# Cycle 823: Best Fitness = 3757.870641829796
# Cycle 824: Best Fitness = 3757.870641829796
# Cycle 825: Best Fitness = 3757.870641829796
# Cycle 826: Best Fitness = 3757.870641829796
# Cycle 827: Best Fitness = 3753.76382905928
# Cycle 828: Best Fitness = 3753.76382905928
# Cycle 829: Best Fitness = 3753.76382905928
# Cycle 830: Best Fitness = 3753.76382905928
# Cycle 831: Best Fitness = 3753.76382905928
# Cycle 832: Best Fitness = 3753.76382905928
# Cycle 833: Best Fitness = 3748.6211450186283
# Cycle 834: Best Fitness = 3748.6211450186283
# Cycle 835: Best Fitness = 3748.6211450186283
# Cycle 836: Best Fitness = 3746.687583238838
# Cycle 837: Best Fitness = 3745.2726940139687
# Cycle 838: Best Fitness = 3745.2726940139687
# Cycle 839: Best Fitness = 3745.2726940139687
# Cycle 840: Best Fitness = 3745.2726940139687
# Cycle 841: Best Fitness = 3734.2692445915086
# Cycle 842: Best Fitness = 3734.2692445915086
# Cycle 843: Best Fitness = 3734.2692445915086
# Cycle 844: Best Fitness = 3734.2692445915086
# Cycle 845: Best Fitness = 3729.740275242895
# Cycle 846: Best Fitness = 3729.740275242895
# Cycle 847: Best Fitness = 3729.740275242895
# Cycle 848: Best Fitness = 3729.740275242895
# Cycle 849: Best Fitness = 3727.5130156926275
# Cycle 850: Best Fitness = 3727.5130156926275
# Cycle 851: Best Fitness = 3727.5130156926275
# Cycle 852: Best Fitness = 3727.5130156926275
# Cycle 853: Best Fitness = 3727.246338489525
# Cycle 854: Best Fitness = 3722.9900063028863
# Cycle 855: Best Fitness = 3722.9900063028863
# Cycle 856: Best Fitness = 3722.9900063028863
# Cycle 857: Best Fitness = 3722.9900063028863
# Cycle 858: Best Fitness = 3722.9900063028863
# Cycle 859: Best Fitness = 3722.9900063028863
# Cycle 860: Best Fitness = 3722.9900063028863
# Cycle 861: Best Fitness = 3721.3397913288427
# Cycle 862: Best Fitness = 3721.3397913288427
# Cycle 863: Best Fitness = 3721.3397913288427
# Cycle 864: Best Fitness = 3721.3397913288427
# Cycle 865: Best Fitness = 3721.3397913288427
# Cycle 866: Best Fitness = 3721.3397913288427
# Cycle 867: Best Fitness = 3716.892446847122
# Cycle 868: Best Fitness = 3715.908970367329
# Cycle 869: Best Fitness = 3715.0798136420253
# Cycle 870: Best Fitness = 3715.0798136420253
# Cycle 871: Best Fitness = 3709.4299161583476
# Cycle 872: Best Fitness = 3709.4299161583476
# Cycle 873: Best Fitness = 3709.4299161583476
# Cycle 874: Best Fitness = 3709.4299161583476
# Cycle 875: Best Fitness = 3709.4299161583476
# Cycle 876: Best Fitness = 3709.3960337651633
# Cycle 877: Best Fitness = 3709.3960337651633
# Cycle 878: Best Fitness = 3697.8674313707734
# Cycle 879: Best Fitness = 3697.8674313707734
# Cycle 880: Best Fitness = 3697.8674313707734
# Cycle 881: Best Fitness = 3697.8674313707734
# Cycle 882: Best Fitness = 3697.8674313707734
# Cycle 883: Best Fitness = 3697.8674313707734
# Cycle 884: Best Fitness = 3697.149029591135
# Cycle 885: Best Fitness = 3697.149029591135
# Cycle 886: Best Fitness = 3697.149029591135
# Cycle 887: Best Fitness = 3697.149029591135
# Cycle 888: Best Fitness = 3697.149029591135
# Cycle 889: Best Fitness = 3694.953037552298
# Cycle 890: Best Fitness = 3683.9858160606223
# Cycle 891: Best Fitness = 3673.075882824689
# Cycle 892: Best Fitness = 3673.075882824689
# Cycle 893: Best Fitness = 3670.8977372398153
# Cycle 894: Best Fitness = 3670.8419099380762
# Cycle 895: Best Fitness = 3670.8419099380762
# Cycle 896: Best Fitness = 3670.8419099380762
# Cycle 897: Best Fitness = 3670.8419099380762
# Cycle 898: Best Fitness = 3660.1062235625623
# Cycle 899: Best Fitness = 3660.1062235625623
# Cycle 900: Best Fitness = 3652.573668863629
# Cycle 901: Best Fitness = 3647.6627224435715
# Cycle 902: Best Fitness = 3647.6627224435715
# Cycle 903: Best Fitness = 3647.6627224435715
# Cycle 904: Best Fitness = 3644.4303668777475
# Cycle 905: Best Fitness = 3644.4303668777475
# Cycle 906: Best Fitness = 3644.4303668777475
# Cycle 907: Best Fitness = 3644.4303668777475
# Cycle 908: Best Fitness = 3644.4303668777475
# Cycle 909: Best Fitness = 3640.5605069900685
# Cycle 910: Best Fitness = 3640.5605069900685
# Cycle 911: Best Fitness = 3640.5605069900685
# Cycle 912: Best Fitness = 3640.5605069900685
# Cycle 913: Best Fitness = 3640.5605069900685
# Cycle 914: Best Fitness = 3640.5605069900685
# Cycle 915: Best Fitness = 3639.0463937577993
# Cycle 916: Best Fitness = 3639.0463937577993
# Cycle 917: Best Fitness = 3639.0463937577993
# Cycle 918: Best Fitness = 3639.0463937577993
# Cycle 919: Best Fitness = 3639.0463937577993
# Cycle 920: Best Fitness = 3639.0463937577993
# Cycle 921: Best Fitness = 3639.0463937577993
# Cycle 922: Best Fitness = 3639.0463937577993
# Cycle 923: Best Fitness = 3639.0463937577993
# Cycle 924: Best Fitness = 3639.0463937577993
# Cycle 925: Best Fitness = 3638.208819563818
# Cycle 926: Best Fitness = 3638.208819563818
# Cycle 927: Best Fitness = 3638.208819563818
# Cycle 928: Best Fitness = 3631.91872850563
# Cycle 929: Best Fitness = 3631.91872850563
# Cycle 930: Best Fitness = 3631.91872850563
# Cycle 931: Best Fitness = 3631.7418632284944
# Cycle 932: Best Fitness = 3631.7418632284944
# Cycle 933: Best Fitness = 3631.7418632284944
# Cycle 934: Best Fitness = 3622.6368754101277
# Cycle 935: Best Fitness = 3622.6368754101277
# Cycle 936: Best Fitness = 3617.8242030227157
# Cycle 937: Best Fitness = 3617.8242030227157
# Cycle 938: Best Fitness = 3616.55898648445
# Cycle 939: Best Fitness = 3616.55898648445
# Cycle 940: Best Fitness = 3616.55898648445
# Cycle 941: Best Fitness = 3616.55898648445
# Cycle 942: Best Fitness = 3616.1212168272514
# Cycle 943: Best Fitness = 3609.1651614210755
# Cycle 944: Best Fitness = 3602.668185328404
# Cycle 945: Best Fitness = 3602.668185328404
# Cycle 946: Best Fitness = 3602.3050621249704
# Cycle 947: Best Fitness = 3602.3050621249704
# Cycle 948: Best Fitness = 3598.3561943994805
# Cycle 949: Best Fitness = 3598.3561943994805
# Cycle 950: Best Fitness = 3597.2994461681988
# Cycle 951: Best Fitness = 3597.2994461681988
# Cycle 952: Best Fitness = 3597.2994461681988
# Cycle 953: Best Fitness = 3594.8161898043336
# Cycle 954: Best Fitness = 3583.117920431707
# Cycle 955: Best Fitness = 3578.1419706729203
# Cycle 956: Best Fitness = 3577.8505175572836
# Cycle 957: Best Fitness = 3577.8505175572836
# Cycle 958: Best Fitness = 3577.8505175572836
# Cycle 959: Best Fitness = 3566.784970388188
# Cycle 960: Best Fitness = 3566.784970388188
# Cycle 961: Best Fitness = 3566.784970388188
# Cycle 962: Best Fitness = 3560.249705006002
# Cycle 963: Best Fitness = 3556.63558826789
# Cycle 964: Best Fitness = 3541.290163380286
# Cycle 965: Best Fitness = 3533.926615883326
# Cycle 966: Best Fitness = 3533.926615883326
# Cycle 967: Best Fitness = 3533.926615883326
# Cycle 968: Best Fitness = 3533.926615883326
# Cycle 969: Best Fitness = 3533.926615883326
# Cycle 970: Best Fitness = 3523.259541294619
# Cycle 971: Best Fitness = 3523.259541294619
# Cycle 972: Best Fitness = 3523.259541294619
# Cycle 973: Best Fitness = 3523.259541294619
# Cycle 974: Best Fitness = 3513.6087605935027
# Cycle 975: Best Fitness = 3513.6087605935027
# Cycle 976: Best Fitness = 3508.1329993675145
# Cycle 977: Best Fitness = 3508.1329993675145
# Cycle 978: Best Fitness = 3508.1329993675145
# Cycle 979: Best Fitness = 3508.1329993675145
# Cycle 980: Best Fitness = 3508.1329993675145
# Cycle 981: Best Fitness = 3508.1329993675145
# Cycle 982: Best Fitness = 3508.1329993675145
# Cycle 983: Best Fitness = 3508.1329993675145
# Cycle 984: Best Fitness = 3506.8839273354893
# Cycle 985: Best Fitness = 3506.8839273354893
# Cycle 986: Best Fitness = 3492.391533075767
# Cycle 987: Best Fitness = 3490.104290728714
# Cycle 988: Best Fitness = 3490.104290728714
# Cycle 989: Best Fitness = 3490.104290728714
# Cycle 990: Best Fitness = 3490.104290728714
# Cycle 991: Best Fitness = 3490.104290728714
# Cycle 992: Best Fitness = 3490.104290728714
# Cycle 993: Best Fitness = 3490.104290728714
# Cycle 994: Best Fitness = 3490.104290728714
# Cycle 995: Best Fitness = 3490.104290728714
# Cycle 996: Best Fitness = 3490.104290728714
# Cycle 997: Best Fitness = 3488.2172530805965
# Cycle 998: Best Fitness = 3484.3303304305696
# Cycle 999: Best Fitness = 3478.379289207197
# Cycle 1000: Best Fitness = 3478.379289207197
# Cycle 1001: Best Fitness = 3478.379289207197
# Cycle 1002: Best Fitness = 3478.379289207197
# Cycle 1003: Best Fitness = 3478.379289207197
# Cycle 1004: Best Fitness = 3478.379289207197
# Cycle 1005: Best Fitness = 3478.379289207197
# Cycle 1006: Best Fitness = 3478.379289207197
# Cycle 1007: Best Fitness = 3478.379289207197
# Cycle 1008: Best Fitness = 3478.379289207197
# Cycle 1009: Best Fitness = 3477.5692245718674
# Cycle 1010: Best Fitness = 3476.348660174145
# Cycle 1011: Best Fitness = 3476.242179984224
# Cycle 1012: Best Fitness = 3476.242179984224
# Cycle 1013: Best Fitness = 3476.242179984224
# Cycle 1014: Best Fitness = 3475.3371904942833
# Cycle 1015: Best Fitness = 3475.3371904942833
# Cycle 1016: Best Fitness = 3471.7695941018974
# Cycle 1017: Best Fitness = 3471.7695941018974
# Cycle 1018: Best Fitness = 3471.7695941018974
# Cycle 1019: Best Fitness = 3471.7695941018974
# Cycle 1020: Best Fitness = 3471.7695941018974
# Cycle 1021: Best Fitness = 3470.0986255286152
# Cycle 1022: Best Fitness = 3470.0986255286152
# Cycle 1023: Best Fitness = 3469.158117891252
# Cycle 1024: Best Fitness = 3469.158117891252
# Cycle 1025: Best Fitness = 3469.158117891252
# Cycle 1026: Best Fitness = 3464.475143155014
# Cycle 1027: Best Fitness = 3464.475143155014
# Cycle 1028: Best Fitness = 3464.475143155014
# Cycle 1029: Best Fitness = 3464.475143155014
# Cycle 1030: Best Fitness = 3464.475143155014
# Cycle 1031: Best Fitness = 3464.475143155014
# Cycle 1032: Best Fitness = 3462.6393433421963
# Cycle 1033: Best Fitness = 3462.6393433421963
# Cycle 1034: Best Fitness = 3462.6393433421963
# Cycle 1035: Best Fitness = 3462.6393433421963
# Cycle 1036: Best Fitness = 3460.8843835326625
# Cycle 1037: Best Fitness = 3460.322391622408
# Cycle 1038: Best Fitness = 3460.322391622408
# Cycle 1039: Best Fitness = 3446.8922268682363
# Cycle 1040: Best Fitness = 3446.8922268682363
# Cycle 1041: Best Fitness = 3446.8922268682363
# Cycle 1042: Best Fitness = 3446.8922268682363
# Cycle 1043: Best Fitness = 3446.8922268682363
# Cycle 1044: Best Fitness = 3446.8922268682363
# Cycle 1045: Best Fitness = 3417.75101960387
# Cycle 1046: Best Fitness = 3417.75101960387
# Cycle 1047: Best Fitness = 3417.75101960387
# Cycle 1048: Best Fitness = 3412.324175095064
# Cycle 1049: Best Fitness = 3405.912099203244
# Cycle 1050: Best Fitness = 3405.912099203244
# Cycle 1051: Best Fitness = 3405.912099203244
# Cycle 1052: Best Fitness = 3405.912099203244
# Cycle 1053: Best Fitness = 3405.8809763083245
# Cycle 1054: Best Fitness = 3399.6171053828384
# Cycle 1055: Best Fitness = 3399.6171053828384
# Cycle 1056: Best Fitness = 3399.6171053828384
# Cycle 1057: Best Fitness = 3399.6171053828384
# Cycle 1058: Best Fitness = 3399.6171053828384
# Cycle 1059: Best Fitness = 3399.6171053828384
# Cycle 1060: Best Fitness = 3399.6171053828384
# Cycle 1061: Best Fitness = 3399.6171053828384
# Cycle 1062: Best Fitness = 3399.459977061085
# Cycle 1063: Best Fitness = 3399.459977061085
# Cycle 1064: Best Fitness = 3397.6288899788765
# Cycle 1065: Best Fitness = 3397.6210860400925
# Cycle 1066: Best Fitness = 3397.6210860400925
# Cycle 1067: Best Fitness = 3397.6210860400925
# Cycle 1068: Best Fitness = 3397.6210860400925
# Cycle 1069: Best Fitness = 3393.3716839980966
# Cycle 1070: Best Fitness = 3393.3716839980966
# Cycle 1071: Best Fitness = 3393.3716839980966
# Cycle 1072: Best Fitness = 3390.899548043097
# Cycle 1073: Best Fitness = 3390.899548043097
# Cycle 1074: Best Fitness = 3390.899548043097
# Cycle 1075: Best Fitness = 3390.899548043097
# Cycle 1076: Best Fitness = 3380.766098373683
# Cycle 1077: Best Fitness = 3375.901372038492
# Cycle 1078: Best Fitness = 3374.7937923505388
# Cycle 1079: Best Fitness = 3374.7937923505388
# Cycle 1080: Best Fitness = 3374.7937923505388
# Cycle 1081: Best Fitness = 3373.3766977630585
# Cycle 1082: Best Fitness = 3373.3766977630585
# Cycle 1083: Best Fitness = 3361.50910911984
# Cycle 1084: Best Fitness = 3361.50910911984
# ...
# Cycle 4651: Best Fitness = 1904.5003927640896
# Cycle 4652: Best Fitness = 1904.5003927640896
# Cycle 4653: Best Fitness = 1904.5003927640896
# Cycle 4654: Best Fitness = 1904.5003927640896
# Cycle 4655: Best Fitness = 1904.5003927640896
# Cycle 4656: Best Fitness = 1904.5003927640896
# Cycle 4657: Best Fitness = 1903.0384042865421
# Cycle 4658: Best Fitness = 1902.8769357056785
# Cycle 4659: Best Fitness = 1902.8769357056785
# Cycle 4660: Best Fitness = 1902.8769357056785
# Cycle 4661: Best Fitness = 1902.8769357056785
# Cycle 4662: Best Fitness = 1902.8769357056785
# Cycle 4663: Best Fitness = 1902.8769357056785
# Cycle 4664: Best Fitness = 1902.8769357056785
# Cycle 4665: Best Fitness = 1902.8769357056785
# Cycle 4666: Best Fitness = 1902.8769357056785
# Cycle 4667: Best Fitness = 1902.8769357056785
# Cycle 4668: Best Fitness = 1902.8769357056785
# Cycle 4669: Best Fitness = 1902.8769357056785
# Cycle 4670: Best Fitness = 1902.8769357056785
# Cycle 4671: Best Fitness = 1902.8769357056785
# Cycle 4672: Best Fitness = 1902.8769357056785
# Cycle 4673: Best Fitness = 1902.8769357056785
# Cycle 4674: Best Fitness = 1902.8769357056785
# Cycle 4675: Best Fitness = 1902.8769357056785
# Cycle 4676: Best Fitness = 1902.8769357056785
# Cycle 4677: Best Fitness = 1899.4937418596905
# Cycle 4678: Best Fitness = 1899.4937418596905
# Cycle 4679: Best Fitness = 1899.4937418596905
# Cycle 4680: Best Fitness = 1899.4937418596905
# Cycle 4681: Best Fitness = 1899.4937418596905
# Cycle 4682: Best Fitness = 1899.4937418596905
# Cycle 4683: Best Fitness = 1899.4937418596905
# Cycle 4684: Best Fitness = 1899.4937418596905
# Cycle 4685: Best Fitness = 1899.4937418596905
# Cycle 4686: Best Fitness = 1899.4937418596905
# Cycle 4687: Best Fitness = 1899.4937418596905
# Cycle 4688: Best Fitness = 1899.4937418596905
# Cycle 4689: Best Fitness = 1899.4937418596905
# Cycle 4690: Best Fitness = 1899.4937418596905
# Cycle 4691: Best Fitness = 1899.4937418596905
# Cycle 4692: Best Fitness = 1899.4937418596905
# Cycle 4693: Best Fitness = 1899.4937418596905
# Cycle 4694: Best Fitness = 1899.4937418596905
# Cycle 4695: Best Fitness = 1899.4937418596905
# Cycle 4696: Best Fitness = 1899.4937418596905
# Cycle 4697: Best Fitness = 1899.4937418596905
# Cycle 4698: Best Fitness = 1899.4937418596905
# Cycle 4699: Best Fitness = 1899.4937418596905
# Cycle 4700: Best Fitness = 1899.4937418596905
# Cycle 4701: Best Fitness = 1899.4937418596905
# Cycle 4702: Best Fitness = 1888.6275270699743
# Cycle 4703: Best Fitness = 1888.6275270699743
# Cycle 4704: Best Fitness = 1888.6275270699743
# Cycle 4705: Best Fitness = 1885.884814703466
# Cycle 4706: Best Fitness = 1885.884814703466
# Cycle 4707: Best Fitness = 1885.884814703466
# Cycle 4708: Best Fitness = 1885.884814703466
# Cycle 4709: Best Fitness = 1885.884814703466
# Cycle 4710: Best Fitness = 1885.884814703466
# Cycle 4711: Best Fitness = 1885.884814703466
# Cycle 4712: Best Fitness = 1885.884814703466
# Cycle 4713: Best Fitness = 1885.884814703466
# Cycle 4714: Best Fitness = 1885.884814703466
# Cycle 4715: Best Fitness = 1877.361819304264
# Cycle 4716: Best Fitness = 1877.361819304264
# Cycle 4717: Best Fitness = 1873.8310728258925
# Cycle 4718: Best Fitness = 1873.8310728258925
# Cycle 4719: Best Fitness = 1873.8310728258925
# Cycle 4720: Best Fitness = 1868.617480894012
# Cycle 4721: Best Fitness = 1868.617480894012
# Cycle 4722: Best Fitness = 1868.617480894012
# Cycle 4723: Best Fitness = 1868.617480894012
# Cycle 4724: Best Fitness = 1868.617480894012
# Cycle 4725: Best Fitness = 1868.617480894012
# Cycle 4726: Best Fitness = 1868.617480894012
# Cycle 4727: Best Fitness = 1868.617480894012
# Cycle 4728: Best Fitness = 1868.617480894012
# Cycle 4729: Best Fitness = 1868.617480894012
# Cycle 4730: Best Fitness = 1868.617480894012
# Cycle 4731: Best Fitness = 1868.617480894012
# Cycle 4732: Best Fitness = 1868.617480894012
# Cycle 4733: Best Fitness = 1868.617480894012
# Cycle 4734: Best Fitness = 1868.617480894012
# Cycle 4735: Best Fitness = 1867.5617528040111
# Cycle 4736: Best Fitness = 1867.5617528040111
# Cycle 4737: Best Fitness = 1867.5617528040111
# Cycle 4738: Best Fitness = 1867.5617528040111
# Cycle 4739: Best Fitness = 1867.5617528040111
# Cycle 4740: Best Fitness = 1867.5617528040111
# Cycle 4741: Best Fitness = 1867.5617528040111
# Cycle 4742: Best Fitness = 1867.5617528040111
# Cycle 4743: Best Fitness = 1865.6438297613006
# Cycle 4744: Best Fitness = 1865.6438297613006
# Cycle 4745: Best Fitness = 1865.6438297613006
# Cycle 4746: Best Fitness = 1865.6438297613006
# Cycle 4747: Best Fitness = 1863.1585129757675
# Cycle 4748: Best Fitness = 1863.1585129757675
# Cycle 4749: Best Fitness = 1863.1585129757675
# Cycle 4750: Best Fitness = 1863.1585129757675
# Cycle 4751: Best Fitness = 1863.1585129757675
# Cycle 4752: Best Fitness = 1863.1585129757675
# Cycle 4753: Best Fitness = 1863.0426681905146
# Cycle 4754: Best Fitness = 1863.0426681905146
# Cycle 4755: Best Fitness = 1860.589172744819
# Cycle 4756: Best Fitness = 1860.589172744819
# Cycle 4757: Best Fitness = 1860.589172744819
# Cycle 4758: Best Fitness = 1860.589172744819
# Cycle 4759: Best Fitness = 1860.589172744819
# Cycle 4760: Best Fitness = 1860.589172744819
# Cycle 4761: Best Fitness = 1860.589172744819
# Cycle 4762: Best Fitness = 1860.589172744819
# Cycle 4763: Best Fitness = 1860.589172744819
# Cycle 4764: Best Fitness = 1860.589172744819
# Cycle 4765: Best Fitness = 1860.589172744819
# Cycle 4766: Best Fitness = 1860.589172744819
# Cycle 4767: Best Fitness = 1860.589172744819
# Cycle 4768: Best Fitness = 1860.589172744819
# Cycle 4769: Best Fitness = 1856.8579908517552
# Cycle 4770: Best Fitness = 1856.8579908517552
# Cycle 4771: Best Fitness = 1856.8579908517552
# Cycle 4772: Best Fitness = 1856.8579908517552
# Cycle 4773: Best Fitness = 1856.8579908517552
# Cycle 4774: Best Fitness = 1856.8579908517552
# Cycle 4775: Best Fitness = 1856.8579908517552
# Cycle 4776: Best Fitness = 1856.8579908517552
# Cycle 4777: Best Fitness = 1856.8579908517552
# Cycle 4778: Best Fitness = 1856.8579908517552
# Cycle 4779: Best Fitness = 1856.8579908517552
# Cycle 4780: Best Fitness = 1856.8579908517552
# Cycle 4781: Best Fitness = 1856.8579908517552
# Cycle 4782: Best Fitness = 1856.8579908517552
# Cycle 4783: Best Fitness = 1856.8579908517552
# Cycle 4784: Best Fitness = 1856.8579908517552
# Cycle 4785: Best Fitness = 1856.8579908517552
# Cycle 4786: Best Fitness = 1856.8579908517552
# Cycle 4787: Best Fitness = 1856.8579908517552
# Cycle 4788: Best Fitness = 1856.8579908517552
# Cycle 4789: Best Fitness = 1856.8579908517552
# Cycle 4790: Best Fitness = 1856.8579908517552
# Cycle 4791: Best Fitness = 1856.8579908517552
# Cycle 4792: Best Fitness = 1856.8579908517552
# Cycle 4793: Best Fitness = 1856.8579908517552
# Cycle 4794: Best Fitness = 1856.8579908517552
# Cycle 4795: Best Fitness = 1856.8579908517552
# Cycle 4796: Best Fitness = 1856.8579908517552
# Cycle 4797: Best Fitness = 1856.8579908517552
# Cycle 4798: Best Fitness = 1856.8579908517552
# Cycle 4799: Best Fitness = 1856.8579908517552
# Cycle 4800: Best Fitness = 1856.8579908517552
# Cycle 4801: Best Fitness = 1856.8579908517552
# Cycle 4802: Best Fitness = 1854.0493285648463
# Cycle 4803: Best Fitness = 1854.0493285648463
# Cycle 4804: Best Fitness = 1854.0493285648463
# Cycle 4805: Best Fitness = 1854.0493285648463
# Cycle 4806: Best Fitness = 1854.0493285648463
# Cycle 4807: Best Fitness = 1854.0493285648463
# Cycle 4808: Best Fitness = 1854.0493285648463
# Cycle 4809: Best Fitness = 1854.0493285648463
# Cycle 4810: Best Fitness = 1854.0493285648463
# Cycle 4811: Best Fitness = 1854.0493285648463
# Cycle 4812: Best Fitness = 1854.0493285648463
# Cycle 4813: Best Fitness = 1854.0493285648463
# Cycle 4814: Best Fitness = 1854.0493285648463
# Cycle 4815: Best Fitness = 1854.0493285648463
# Cycle 4816: Best Fitness = 1852.00823144388
# Cycle 4817: Best Fitness = 1852.00823144388
# Cycle 4818: Best Fitness = 1852.00823144388
# Cycle 4819: Best Fitness = 1852.00823144388
# Cycle 4820: Best Fitness = 1852.00823144388
# Cycle 4821: Best Fitness = 1852.00823144388
# Cycle 4822: Best Fitness = 1852.00823144388
# Cycle 4823: Best Fitness = 1852.00823144388
# Cycle 4824: Best Fitness = 1852.00823144388
# Cycle 4825: Best Fitness = 1852.00823144388
# Cycle 4826: Best Fitness = 1852.00823144388
# Cycle 4827: Best Fitness = 1852.00823144388
# Cycle 4828: Best Fitness = 1851.507930042017
# Cycle 4829: Best Fitness = 1851.507930042017
# Cycle 4830: Best Fitness = 1851.507930042017
# Cycle 4831: Best Fitness = 1851.507930042017
# Cycle 4832: Best Fitness = 1851.507930042017
# Cycle 4833: Best Fitness = 1851.507930042017
# Cycle 4834: Best Fitness = 1851.507930042017
# Cycle 4835: Best Fitness = 1851.507930042017
# Cycle 4836: Best Fitness = 1851.507930042017
# Cycle 4837: Best Fitness = 1851.507930042017
# Cycle 4838: Best Fitness = 1851.507930042017
# Cycle 4839: Best Fitness = 1851.507930042017
# Cycle 4840: Best Fitness = 1851.507930042017
# Cycle 4841: Best Fitness = 1851.507930042017
# Cycle 4842: Best Fitness = 1851.507930042017
# Cycle 4843: Best Fitness = 1851.507930042017
# Cycle 4844: Best Fitness = 1851.507930042017
# Cycle 4845: Best Fitness = 1851.507930042017
# Cycle 4846: Best Fitness = 1851.507930042017
# Cycle 4847: Best Fitness = 1851.507930042017
# Cycle 4848: Best Fitness = 1851.507930042017
# Cycle 4849: Best Fitness = 1851.507930042017
# Cycle 4850: Best Fitness = 1851.507930042017
# Cycle 4851: Best Fitness = 1851.507930042017
# Cycle 4852: Best Fitness = 1851.507930042017
# Cycle 4853: Best Fitness = 1851.507930042017
# Cycle 4854: Best Fitness = 1847.1010172219271
# Cycle 4855: Best Fitness = 1847.1010172219271
# Cycle 4856: Best Fitness = 1847.1010172219271
# Cycle 4857: Best Fitness = 1847.1010172219271
# Cycle 4858: Best Fitness = 1847.1010172219271
# Cycle 4859: Best Fitness = 1847.1010172219271
# Cycle 4860: Best Fitness = 1846.7490614078527
# Cycle 4861: Best Fitness = 1846.7490614078527
# Cycle 4862: Best Fitness = 1846.7490614078527
# Cycle 4863: Best Fitness = 1846.7490614078527
# Cycle 4864: Best Fitness = 1846.7490614078527
# Cycle 4865: Best Fitness = 1846.7490614078527
# Cycle 4866: Best Fitness = 1846.7490614078527
# Cycle 4867: Best Fitness = 1846.7490614078527
# Cycle 4868: Best Fitness = 1846.7490614078527
# Cycle 4869: Best Fitness = 1846.7490614078527
# Cycle 4870: Best Fitness = 1846.7490614078527
# Cycle 4871: Best Fitness = 1846.7490614078527
# Cycle 4872: Best Fitness = 1846.7490614078527
# Cycle 4873: Best Fitness = 1846.7490614078527
# Cycle 4874: Best Fitness = 1846.7490614078527
# Cycle 4875: Best Fitness = 1843.5774885325989
# Cycle 4876: Best Fitness = 1843.5774885325989
# Cycle 4877: Best Fitness = 1843.5774885325989
# Cycle 4878: Best Fitness = 1843.5774885325989
# Cycle 4879: Best Fitness = 1840.0467420542277
# Cycle 4880: Best Fitness = 1840.0467420542277
# Cycle 4881: Best Fitness = 1839.3865072681342
# Cycle 4882: Best Fitness = 1839.3865072681342
# Cycle 4883: Best Fitness = 1839.3865072681342
# Cycle 4884: Best Fitness = 1839.3865072681342
# Cycle 4885: Best Fitness = 1839.3865072681342
# Cycle 4886: Best Fitness = 1839.3865072681342
# Cycle 4887: Best Fitness = 1839.3865072681342
# Cycle 4888: Best Fitness = 1839.3865072681342
# Cycle 4889: Best Fitness = 1839.3865072681342
# Cycle 4890: Best Fitness = 1839.3865072681342
# Cycle 4891: Best Fitness = 1839.3865072681342
# Cycle 4892: Best Fitness = 1839.125210094373
# Cycle 4893: Best Fitness = 1836.487805951237
# Cycle 4894: Best Fitness = 1836.487805951237
# Cycle 4895: Best Fitness = 1836.487805951237
# Cycle 4896: Best Fitness = 1836.487805951237
# Cycle 4897: Best Fitness = 1836.487805951237
# Cycle 4898: Best Fitness = 1836.487805951237
# Cycle 4899: Best Fitness = 1836.487805951237
# Cycle 4900: Best Fitness = 1836.487805951237
# Cycle 4901: Best Fitness = 1836.487805951237
# Cycle 4902: Best Fitness = 1836.487805951237
# Cycle 4903: Best Fitness = 1836.487805951237
# Cycle 4904: Best Fitness = 1836.487805951237
# Cycle 4905: Best Fitness = 1836.487805951237
# Cycle 4906: Best Fitness = 1836.487805951237
# Cycle 4907: Best Fitness = 1836.487805951237
# Cycle 4908: Best Fitness = 1836.487805951237
# Cycle 4909: Best Fitness = 1836.487805951237
# Cycle 4910: Best Fitness = 1836.487805951237
# Cycle 4911: Best Fitness = 1836.487805951237
# Cycle 4912: Best Fitness = 1836.487805951237
# Cycle 4913: Best Fitness = 1836.487805951237
# Cycle 4914: Best Fitness = 1836.487805951237
# Cycle 4915: Best Fitness = 1836.487805951237
# Cycle 4916: Best Fitness = 1836.487805951237
# Cycle 4917: Best Fitness = 1836.487805951237
# Cycle 4918: Best Fitness = 1836.487805951237
# Cycle 4919: Best Fitness = 1836.487805951237
# Cycle 4920: Best Fitness = 1836.487805951237
# Cycle 4921: Best Fitness = 1836.487805951237
# Cycle 4922: Best Fitness = 1836.487805951237
# Cycle 4923: Best Fitness = 1836.487805951237
# Cycle 4924: Best Fitness = 1836.487805951237
# Cycle 4925: Best Fitness = 1836.487805951237
# Cycle 4926: Best Fitness = 1836.487805951237
# Cycle 4927: Best Fitness = 1836.487805951237
# Cycle 4928: Best Fitness = 1836.487805951237
# Cycle 4929: Best Fitness = 1836.487805951237
# Cycle 4930: Best Fitness = 1836.487805951237
# Cycle 4931: Best Fitness = 1836.487805951237
# Cycle 4932: Best Fitness = 1836.487805951237
# Cycle 4933: Best Fitness = 1836.487805951237
# Cycle 4934: Best Fitness = 1836.487805951237
# Cycle 4935: Best Fitness = 1836.487805951237
# Cycle 4936: Best Fitness = 1836.487805951237
# Cycle 4937: Best Fitness = 1836.487805951237
# Cycle 4938: Best Fitness = 1836.487805951237
# Cycle 4939: Best Fitness = 1836.487805951237
# Cycle 4940: Best Fitness = 1836.487805951237
# Cycle 4941: Best Fitness = 1836.487805951237
# Cycle 4942: Best Fitness = 1836.487805951237
# Cycle 4943: Best Fitness = 1836.487805951237
# Cycle 4944: Best Fitness = 1836.487805951237
# Cycle 4945: Best Fitness = 1836.487805951237
# Cycle 4946: Best Fitness = 1836.487805951237
# Cycle 4947: Best Fitness = 1836.487805951237
# Cycle 4948: Best Fitness = 1836.487805951237
# Cycle 4949: Best Fitness = 1830.594698473268
# Cycle 4950: Best Fitness = 1830.594698473268
# Cycle 4951: Best Fitness = 1830.594698473268
# Cycle 4952: Best Fitness = 1830.594698473268
# Cycle 4953: Best Fitness = 1830.594698473268
# Cycle 4954: Best Fitness = 1830.594698473268
# Cycle 4955: Best Fitness = 1830.594698473268
# Cycle 4956: Best Fitness = 1830.594698473268
# Cycle 4957: Best Fitness = 1830.594698473268
# Cycle 4958: Best Fitness = 1830.594698473268
# Cycle 4959: Best Fitness = 1830.594698473268
# Cycle 4960: Best Fitness = 1830.594698473268
# Cycle 4961: Best Fitness = 1830.594698473268
# Cycle 4962: Best Fitness = 1830.594698473268
# Cycle 4963: Best Fitness = 1830.594698473268
# Cycle 4964: Best Fitness = 1830.594698473268
# Cycle 4965: Best Fitness = 1830.594698473268
# Cycle 4966: Best Fitness = 1830.594698473268
# Cycle 4967: Best Fitness = 1830.594698473268
# Cycle 4968: Best Fitness = 1830.594698473268
# Cycle 4969: Best Fitness = 1830.594698473268
# Cycle 4970: Best Fitness = 1830.594698473268
# Cycle 4971: Best Fitness = 1830.594698473268
# Cycle 4972: Best Fitness = 1830.594698473268
# Cycle 4973: Best Fitness = 1830.594698473268
# Cycle 4974: Best Fitness = 1827.1769143467789
# Cycle 4975: Best Fitness = 1827.1769143467789
# Cycle 4976: Best Fitness = 1827.1769143467789
# Cycle 4977: Best Fitness = 1827.1769143467789
# Cycle 4978: Best Fitness = 1827.1769143467789
# Cycle 4979: Best Fitness = 1827.1769143467789
# Cycle 4980: Best Fitness = 1827.1769143467789
# Cycle 4981: Best Fitness = 1827.1769143467789
# Cycle 4982: Best Fitness = 1827.1769143467789
# Cycle 4983: Best Fitness = 1827.1769143467789
# Cycle 4984: Best Fitness = 1827.1769143467789
# Cycle 4985: Best Fitness = 1827.1769143467789
# Cycle 4986: Best Fitness = 1827.1769143467789
# Cycle 4987: Best Fitness = 1827.1769143467789
# Cycle 4988: Best Fitness = 1827.1769143467789
# Cycle 4989: Best Fitness = 1827.1769143467789
# Cycle 4990: Best Fitness = 1823.4921083955594
# Cycle 4991: Best Fitness = 1821.899749248313
# Cycle 4992: Best Fitness = 1821.899749248313
# Cycle 4993: Best Fitness = 1821.899749248313
# Cycle 4994: Best Fitness = 1821.899749248313
# Cycle 4995: Best Fitness = 1821.899749248313
# Cycle 4996: Best Fitness = 1821.899749248313
# Cycle 4997: Best Fitness = 1821.899749248313
# Cycle 4998: Best Fitness = 1821.899749248313
# Cycle 4999: Best Fitness = 1821.899749248313
# Cycle 5000: Best Fitness = 1821.899749248313
# Best solution: 1821.899749248313
# Execution Time: 144.52 seconds
